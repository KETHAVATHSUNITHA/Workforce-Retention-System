# %% [markdown]
# <a href="https://colab.research.google.com/github/KETHAVATHSUNITHA/Workforce-Retention-System/blob/main/my__pandas_Notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#pandas is more advanced than advanced excel
#pandas --> Mc Kinney--->2008
#what is pandas?
#open source library, mainly works with relational or lebeled data base
#why we are using pandas?
#fast, high-performance, and productive
#what is the functions of pandas?
#Analysing, cleaning, exploring,manipulating the data

# %%
#what is Data Cleaning?
#delete irrelevent rows/ wrong values, empty or null values, and correction of data types,duplicates..etc

# %%
#why we are using pandas?
"""1. fast and efficient data manipulation and analysing
   2. easy to load the data
   3. easy to insert and delete the columns
   4. flexible reshaping and pivoting the data sets
   5. time series analysis and functionality
   6. data visualisation
   7. split-apply-combine operations
   8. group by functionality"""
# Out:
# '1. fast and efficient data manipulation and analysing\n   2. easy to load the data\n   3. easy to insert and delete the columns\n   4. flexible reshaping and pivoting the data sets\n   5. time series analysis and functionality\n   6. data visualisation\n   7. split-apply-combine operations\n   8. group by functionality'

# %% [markdown]
# **installation of pandas**

# %%
# !pip install pandas

# %%
#what is pip?
#pip is a python package manager
#what is module?
#module is a file where it is having predefined functions and global varaibles
#what is library
#it is also similar to module where it is having inbuilt codes

# %%
#import pandas
import pandas as pd

# %%
#How many types of data structures do we have in pandas?
#there are 3types
#1d-->series, 2d--->dataframe, 3d--->panel

# %% [markdown]
# #1D--> Series
#
# series are nothing 1d labeled array which holds --> int,float,str,object

# %%
import numpy as np

# %%
a = np.array([1,2,3,4])
print(a)
a.ndim  #to find the dimesionality of an array
a
# Out:
# [1 2 3 4]
# array([1, 2, 3, 4])

# %%
print(a[0])
print(a[2])
# Out:
# 1
# 3

# %%
sr = pd.Series(a)
print(sr)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# dtype: int64

# %%
#HOW can we change the lables
sr = pd.Series(a,index=['a','b','c','d'])
print(sr)
# Out:
# a    1
# b    2
# c    3
# d    4
# dtype: int64

# %%
#create a series from the dictionary?
d = {"name":"shah",
     "age":28,
     "occupation":"ds",
     "address":'hyderabad'}
sr = pd.Series(d)
print(sr)
print(type(sr))
#how can we represent series in pandas?
#<class 'pandas.core.series.Series'>
# Out:
# name               shah
# age                  28
# occupation           ds
# address       hyderabad
# dtype: object
# <class 'pandas.core.series.Series'>

# %%
#change the labels as "a b c d"---> we cannot rreplace the labels from dictionary in series
sr = pd.Series(d,index=['a','b','c','d'])
print(sr)
# Out:
# a    NaN
# b    NaN
# c    NaN
# d    NaN
# dtype: object

# %%
#print the dictionary with specific key values -->yes we can do provide key names in the index
sr = pd.Series(d,index=['name','age'])
print(sr)
# Out:
# name    shah
# age       28
# dtype: object

# %%
h = ("apple","banana","pinepple","lemon")
sr = pd.Series(h,index=['a','b','c','d'])
print(sr)
# Out:
# a       apple
# b      banana
# c    pinepple
# d       lemon
# dtype: object

# %%
#can we create a series from set?
u = {'apple','banana','pineapple'}
sr = pd.Series(u)   #'set' type is unordered
print(sr)
#note:- we cannot build the series from sets bcz it is unordered

# %% [markdown]
# series
#
# how can we create series-->   pd.Series(collection_name)
#
# how can we chnage labels---> pd.Series(collection_name, index=['a','b'...etc])
#
# can we create a series from sets---> no bcz sets are unordered

# %% [markdown]
# #2D --> DataFrame

# %%
#what is a dataframe>
#2d-size, mutable, heterogenous data with labeled axis(rows and columns)
#cols:- is also known as  "features", 'varaibles','fields','dimension'
#rows:- is also known as 'records','values','index'

# %%
#what is the applications of df?
#works on datasets
#analysis
#dropping
#processing
#cleaning
#join the multiple data
#create,excel,csv,json,binary files
#compute mathametical and statistical operations
#use groupby functions

# %% [markdown]
# 30-11-2024

# %%
import pandas as pd

# %%
#create a data frame
data = {"name":"a", "b":[1,2],"c":[11,12],"d":"apple"}
print(data)
# Out:
# {'name': 'a', 'b': [1, 2], 'c': [11, 12], 'd': 'apple'}

# %%
df = pd.DataFrame(data)
print(df)
# Out:
#   name  b   c      d
# 0    a  1  11  apple
# 1    a  2  12  apple

# %%
l = [1,2,3,4]
df=pd.DataFrame(l)
df
# Out:
#    0
# 0  1
# 1  2
# 2  3
# 3  4

# %%
#can we create a dataframe from set-->yes
s1 = {1,2,3,4}
s2 = {"apple","banana","apple","lemon"}
df = pd.DataFrame(s2)
df
# Out:
#         0
# 0  banana
# 1   lemon
# 2   apple

# %% [markdown]
# **importing and exporting the Data Frames**

# %%
#1.CSV ---> comma,seprate,value
#read the csv file by using the pandas
df = pd.read_csv("/content/sample_data/california_housing_train.csv")
#read the content the csv for i want to read 1st 5 rows in above df
df.head() #df.head() by default prints 5 rows
#how can i read 10 rows
df.head(10)
#convert or export the df in to excel file
#syntax:- df.to_excel("fill_nmae.xlsx")
df.to_excel("sample.xlsx")

# %%
#red the excel file by uing the pandas
#pd.read_excel
df2 = pd.read_excel("/content/sample.xlsx")
#i want to read last 5 roes of the data
df2.tail() #by default tail() can read last 5 rows
#convert the above excel file to the json format
df2.to_json('sample.json')

# %% [markdown]
# **Data Frame function**

# %%
#take any csv file
#step1:-- read the data
df = pd.read_csv("/content/sample_data/california_housing_train.csv")

# %%
#step2:- check the size and index of the df
df.size       # size---> No.of rows * No of columns
#index--> gives the range of index start to end(start,stop,step)
df.index
# Out:
# RangeIndex(start=0, stop=17000, step=1)

# %%
#read the columns of your df
#i want to know what are all col names
df.columns
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'median_house_value'],
#       dtype='object')

# %%
#how can i get the overall information of df
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17000 entries, 0 to 16999
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           17000 non-null  float64
#  1   latitude            17000 non-null  float64
#  2   housing_median_age  17000 non-null  float64
#  3   total_rooms         17000 non-null  float64
#  4   total_bedrooms      17000 non-null  float64
#  5   population          17000 non-null  float64
#  6   households          17000 non-null  float64
#  7   median_income       17000 non-null  float64
#  8   median_house_value  17000 non-null  float64
# dtypes: float64(9)
# memory usage: 1.2 MB

# %% [markdown]
# This Data set is having 17000 rows and 9 columns
#
# there are no null values
#
# for all the columns the data types is "float"

# %%
#print the dtype for df?
print(df.dtypes)
# Out:
# longitude             float64
# latitude              float64
# housing_median_age    float64
# total_rooms           float64
# total_bedrooms        float64
# population            float64
# households            float64
# median_income         float64
# median_house_value    float64
# dtype: object

# %%
#how to describe the over all data according to statistics?
df.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  17000.000000  17000.000000        17000.000000  17000.000000
# mean    -119.562108     35.625225           28.589353   2643.664412
# std        2.005166      2.137340           12.586937   2179.947071
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.790000     33.930000           18.000000   1462.000000
# 50%     -118.490000     34.250000           29.000000   2127.000000
# 75%     -118.000000     37.720000           37.000000   3151.250000
# max     -114.310000     41.950000           52.000000  37937.000000
#
#        total_bedrooms    population    households  median_income  \
# count    17000.000000  17000.000000  17000.000000   17000.000000
# mean       539.410824   1429.573941    501.221941       3.883578
# std        421.499452   1147.852959    384.520841       1.908157
# min          1.000000      3.000000      1.000000       0.499900
# ...

# %%
#i want to check last 10 rows of my df?
df.tail(10)
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 16990    -124.22     41.73                28.0       3003.0           699.0
# 16991    -124.23     41.75                11.0       3159.0           616.0
# 16992    -124.23     40.81                52.0       1112.0           209.0
# 16993    -124.23     40.54                52.0       2694.0           453.0
# 16994    -124.25     40.28                32.0       1430.0           419.0
# 16995    -124.26     40.58                52.0       2217.0           394.0
# 16996    -124.27     40.69                36.0       2349.0           528.0
# 16997    -124.30     41.84                17.0       2677.0           531.0
# 16998    -124.30     41.80                19.0       2672.0           552.0
# 16999    -124.35     40.54                52.0       1820.0           300.0
#
#        population  households  median_income  median_house_value
# 16990      1530.0       653.0         1.7038             78300.0
# ...

# %%
#check weather the null values present or not?
#df.isna() returns the boolean expression if null values present then it print "True" no null means false
df.isna()
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0          False     False               False        False           False
# 1          False     False               False        False           False
# 2          False     False               False        False           False
# 3          False     False               False        False           False
# 4          False     False               False        False           False
# ...          ...       ...                 ...          ...             ...
# 16995      False     False               False        False           False
# 16996      False     False               False        False           False
# 16997      False     False               False        False           False
# 16998      False     False               False        False           False
# 16999      False     False               False        False           False
#
# ...

# %%
#How to print the sum() null values?
df.isna().sum()
df.isnull().sum()
# Out:
# longitude             0
# latitude              0
# housing_median_age    0
# total_rooms           0
# total_bedrooms        0
# population            0
# households            0
# median_income         0
# median_house_value    0
# dtype: int64

# %%
#how can we drop the null values from df?
df.dropna()
#df.dropna(axis=0,how= any/all, thresh=None,subset=None,inplace= True)
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -114.31     34.19                15.0       5612.0          1283.0
# 1        -114.47     34.40                19.0       7650.0          1901.0
# 2        -114.56     33.69                17.0        720.0           174.0
# 3        -114.57     33.64                14.0       1501.0           337.0
# 4        -114.57     33.57                20.0       1454.0           326.0
# ...          ...       ...                 ...          ...             ...
# 16995    -124.26     40.58                52.0       2217.0           394.0
# 16996    -124.27     40.69                36.0       2349.0           528.0
# 16997    -124.30     41.84                17.0       2677.0           531.0
# 16998    -124.30     41.80                19.0       2672.0           552.0
# 16999    -124.35     40.54                52.0       1820.0           300.0
#
# ...

# %% [markdown]
# **accessing DF**

# %%
df.columns

# %%
#read or access the column total_bedrooms
df['total_bedrooms']
#read 1st 5 ows of the total_bedrooms
df['total_bedrooms'].head()

# %%
#i want to read the 1st row of the tota_bedroom column
df['total_bedrooms'][0]

# %%
#read the mulitple columns at a time from above df
df[['housing_median_age', 'total_rooms','total_bedrooms', 'population', 'households']].head()

# %%
#locating the rows
#use the "df.loc"
#df.loc[index]
df.loc[0]
#df.loc[start:end]
df.loc[2:5]
#read the rows with even and odd position[start:end:step]
df.loc[0:100:2]

# %%
#i want to display the even position characters of particular column
df.loc[0::2, 'total_bedrooms']

# %%
df.loc[0::2,['total_rooms','total_bedrooms']]

# %%
#apply the conditions for the columns
df.loc[df['total_bedrooms']%2 != 0]

# %%
#print the paricuar column value with bedroom with even value
#df['total_bedrooms'] % 2 == 0 #check even and odd values in column
df_even = df[df['total_bedrooms']%2==0]['total_bedrooms']
df_even

# %%
df.shape

# %%
df.loc[[1548,1678,1540]]

# %% [markdown]
# **02-12-2024**

# %%
#iloc:- pass axes numbers for index and columns
import pandas as pd
df = pd.read_csv("/content/sample_data/california_housing_train.csv")

# %%
#print the names of the above df column
df.columns

# %%
#syntax:- df.iloc['row_index','column index']

# %%
df.head()

# %%
#latitude	housing_median_age	total_rooms	total_bedrooms and print1st 3 rows
df.iloc[0:3,1:5]

# %%
df.iloc[1,3]

# %%
df['total_rooms'][1]

# %%
#what is the difference between loc and iloc?
#loc support filtering and iloc doesn't support filtering
#we can apply in the loc and we caanot apply conditions in iloc
df.loc[0:3] #locating the rows
df.loc[df['total_rooms']%2==0]

# %%
df.iloc[df['total_rooms']%2==0] #NotImplementedError: iLocation based boolean indexing on an integer type is not available

# %%
#remove and find the duplices from df
df.duplicated().sum()

# %%
#drop duplicated
df.drop_duplicates(inplace= True)

# %%
#how can we find the unique values?
df['households'].unique()

# %%
df['total_bedrooms'].value_counts()

# %%
#df.head()
#df.tail()
#df.dtypes
#df.shape-->prints the rows and cols
#df.size--->print rows*cols
#df.columns
#df.info()---> print the overall information about df
#df.describe()---> describe the df in the mean of stats
#df.isnull().sum()-->total number of null values
#df.fillna()--> fill the null values
#df.loc[]-->locates the rows
#df.iloc ---> locates elements
#df.duplicated()
#df.drop_duplicates()--->remove duplicates
#df[column_name].unique() -->prints list of uniques value
#df[column_name].value_counts()---> frequenency of each element

# %% [markdown]
# **Applying filters on Data set**

# %%
#How to apply filters on the dataset
#By using the apply()-->it takes an function as an argument and apply to eacj item in the data set
#df.apply(function,convert_dtype=True, arg())

# %%
d = {
    'name': ['a','b','c','d','e'],
    'marks':[56,70,40,80,90]
}
#convert the above dictonary to data_frame
df = pd.DataFrame(d)
df

# %%
#create a function so it can print pass por fail
def funct(num):
  if num >= 45:
    print("pass")
  else:
    print('fail')

# %%
df['marks'].apply(funct)
df['marks']

# %%
#map()by using this method it transforms the values in series  using the specific mapping data
data = {
    'Grades':['A','B','C','D','E'],
}
df = pd.DataFrame(data)
df

# %%
grades = {'A':'Excellent',"B":'good',"c":"Fair","D":"pass","E":"Fail"}
#syntax new_sr = old.sr.map(mapping)
df['Grades'] = df['Grades'].map(grades)
df

# %% [markdown]
# **Time series**

# %%
#what is time series data?
"""Time series data is a sequence of data points in cronological order that is used by
business to analyze the past data and make the future predictions"""
#ex:- weather forcast
#No of taxi rides in a month
#predicting a company stock price for the next day

# %%
#components of the time series
#it is consist of 4 components
#1. Trend Component:- This is a varaiation that moves up or down ina predictable pattern over long period
#2.sesonality component:- The variation  that is regualr and periodic and repeats itself over a specific period
    #ex:- such as days, weeks, or the months, seasons
#3. cyclic component:- is the variation that corresponds with business or economic,  "boom-bust"  cycles it folows their own peculiar cycles
#4.Randomn component:- irregular component

# %%
import pandas as pd
import numpy as np

# %%
#how can we genrate a date range in pandas
#pd.date_range('start date', periods = , freq= )
rng = pd.date_range('1/12/2024',periods = 200, freq = 's')
print(rng)

# %%
ts = pd.Series(np.random.randint(0,200,len(rng)),index = rng)
ts.head()

# %%
ts = pd.Series(np.random.randint(0,200,len(rng)),index=rng)
ts.shape

# %%
#sum the random numbers upto 2min
ts.resample('2min').sum()

# %% [markdown]
# pivot table

# %%
df = pd.DataFrame(
    {
        "A":['one','one','two','three'] *3,
        "B":['A','B','C']*4,
        "C":['food','food','food','drink','drink','drink']*2,
        'D':np.random.randint(0,12, size = 12),
        'E':np.random.randint(0,12,size= 12),

    }
)
df

# %%
#pd.pivot_table()
pd.pivot_table(df,values='D',index=['A','B'],columns=['C'])

# %% [markdown]
# **group by**
#
# -- splitting
#
# -- applying
#
# -- combining

# %%
df = pd.DataFrame(
    {
        "A":['one','one','two','three'] *3,
        "B":['A','B','C']*4,
        "C":['food','food','food','drink','drink','drink']*2,
        'D':np.random.randn(12),
        'E':np.random.randn(12)

    }
)
df

# %%
#grouby function is applicable with the aggregate function
#min, max, sum(),avg, count,median, var,std

# %%
#print the sum of food and drink  for "D" and "E"
df.groupby("C")[["D","E"]].std()

# %%
df.groupby(['A','C']).sum()

# %%
df.describe()

# %% [markdown]
# #Merging 2 data frames

# %%
left = pd.DataFrame({'key':['food','Food'],'lval':[1,2]})
right = pd.DataFrame({'key':['food','Food'],'rval':[3,4]})
pd.merge(left,right, on = "key")

# %%
df

# %%
pieces = [df[:4],df[4:9],df[9:]]
pieces

# %%
#combine this data
pd.concat(pieces)

# %%
https://www.plus2net.com/python/pandas-student.php              #apply all the commands with student data

# %% [markdown]
# **03/12/24**

# %%
import pandas as pd
df = pd.read_csv("/content/student.csv")

# %%
df.head()

# %%
df.head(10)

# %%
df.tail()

# %%
df.size

# %%
df.index

# %%
df.columns

# %%
df.info()

# %%
print(df.dtypes)

# %%
df.describe()

# %%
df.isna()

# %%
df.isnull()

# %%
df.dropna()

# %%
df.loc[0:10]

# %%
df.iloc[0:10]

# %%
df.shape

# %%
df.duplicated()

# %%
df.duplicated().sum()

# %%
df[id].unique()

# %% [markdown]
# # step 1

# %%
import pandas as pd
df = pd.read_csv("/content/movies_metadata(1).csv")
# Out:
# <ipython-input-60-33548a4bc0b8>:2: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("/content/movies_metadata(1).csv")

# %%
df
# Out:
#        adult                              belongs_to_collection    budget  \
# 0      False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1      False                                                NaN  65000000
# 2      False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3      False                                                NaN  16000000
# 4      False  {'id': 96871, 'name': 'Father of the Bride Col...         0
# ...      ...                                                ...       ...
# 45461  False                                                NaN         0
# 45462  False                                                NaN         0
# 45463  False                                                NaN         0
# 45464  False                                                NaN         0
# 45465  False                                                NaN         0
#
#                                                   genres  \
# ...

# %%
df.head()
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
#                                homepage     id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story    862  tt0114709                en
# ...

# %%
df.tail()
# Out:
#        adult belongs_to_collection budget  \
# 45461  False                   NaN      0
# 45462  False                   NaN      0
# 45463  False                   NaN      0
# 45464  False                   NaN      0
# 45465  False                   NaN      0
#
#                                                   genres  \
# 45461  [{'id': 18, 'name': 'Drama'}, {'id': 10751, 'n...
# 45462                      [{'id': 18, 'name': 'Drama'}]
# 45463  [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...
# 45464                                                 []
# 45465                                                 []
#
#                                    homepage      id    imdb_id  \
# 45461  http://www.imdb.com/title/tt6209470/  439050  tt6209470
# 45462                                   NaN  111109  tt2028550
# 45463                                   NaN   67758  tt0303758
# 45464                                   NaN  227506  tt0008536
# ...

# %%
df.shape
# Out:
# (45466, 24)

# %%
df.describe()
# Out:
#             revenue       runtime  vote_average    vote_count
# count  4.546000e+04  45203.000000  45460.000000  45460.000000
# mean   1.120935e+07     94.128199      5.618207    109.897338
# std    6.433225e+07     38.407810      1.924216    491.310374
# min    0.000000e+00      0.000000      0.000000      0.000000
# 25%    0.000000e+00     85.000000      5.000000      3.000000
# 50%    0.000000e+00     95.000000      6.000000     10.000000
# 75%    0.000000e+00    107.000000      6.800000     34.000000
# max    2.787965e+09   1256.000000     10.000000  14075.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45466 entries, 0 to 45465
# Data columns (total 24 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   adult                  45466 non-null  object
#  1   belongs_to_collection  4494 non-null   object
#  2   budget                 45466 non-null  object
#  3   genres                 45466 non-null  object
#  4   homepage               7782 non-null   object
#  5   id                     45466 non-null  object
#  6   imdb_id                45449 non-null  object
#  7   original_language      45455 non-null  object
#  8   original_title         45466 non-null  object
#  9   overview               44512 non-null  object
#  10  popularity             45461 non-null  object
#  11  poster_path            45080 non-null  object
#  12  production_companies   45463 non-null  object
#  13  production_countries   45463 non-null  object
# ...

# %% [markdown]
# #adult

# %%
#print the values
df['adult'].values
# Out:
# array(['False', 'False', 'False', ..., 'False', 'False', 'False'],
#       dtype=object)

# %%
df['adult'].unique()
# Out:
# array(['False', 'True', ' - Written by Ørnås',
#        ' Rune Balot goes to a casino connected to the October corporation to try to wrap up her case once and for all.',
#        ' Avalanche Sharks tells the story of a bikini contest that turns into a horrifying affair when it is hit by a shark avalanche.'],
#       dtype=object)

# %%
df['adult'].isin(['False','True'])
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#          ...
# 45461    True
# 45462    True
# 45463    True
# 45464    True
# 45465    True
# Name: adult, Length: 45466, dtype: bool

# %%
# "~" this except sybol is used to not count
df.loc[~df['adult'].isin(['False','True']),:]
# Out:
#                                                    adult  \
# 19730                                 - Written by Ørnås
# 29503   Rune Balot goes to a casino connected to the ...
# 35587   Avalanche Sharks tells the story of a bikini ...
#
#       belongs_to_collection                            budget  \
# 19730              0.065736  /ff9qCepilowshEtG2GYWwzt2bs4.jpg
# 29503              1.931659  /zV8bHuSL6WXoD6FWogP9j4x80bL.jpg
# 35587              2.185485  /zaSf5OG7V8X8gqFvly88zDdRm46.jpg
#
#                                                   genres  \
# 19730  [{'name': 'Carousel Productions', 'id': 11176}...
# 29503  [{'name': 'Aniplex', 'id': 2883}, {'name': 'Go...
# 35587  [{'name': 'Odyssey Media', 'id': 17161}, {'nam...
#
#                                                 homepage          id imdb_id  \
# 19730  [{'iso_3166_1': 'CA', 'name': 'Canada'}, {'iso...  1997-08-20       0
# 29503  [{'iso_3166_1': 'US', 'name': 'United States o...  2012-09-29       0
# ...

# %%
df['adult'].value_counts()
# Out:
# adult
# False    45454
# True         9
# Name: count, dtype: int64

# %%
#instead of droping my data choose the data
df = df.loc[df['adult'].isin(['False','True']),:]

# %%
df['adult'].value_counts()
# Out:
# adult
# False    45454
# True         9
# Name: count, dtype: int64

# %%
df['adult'].dtypes
df['adult'].unique()
# Out:
# array(['False', 'True'], dtype=object)

# %%
df.dtypes
# Out:
# adult                     object
# belongs_to_collection     object
# budget                    object
# genres                    object
# homepage                  object
# id                        object
# imdb_id                   object
# original_language         object
# original_title            object
# overview                  object
# popularity                object
# poster_path               object
# production_companies      object
# production_countries      object
# release_date              object
# revenue                  float64
# runtime                  float64
# spoken_languages          object
# status                    object
# tagline                   object
# title                     object
# video                     object
# vote_average             float64
# vote_count               float64
# dtype: object

# %%
#use the map function to update the values
df['dult'] = df['adult'].map({'False':False,'True':True})
# Out:
# <ipython-input-76-e7983ff8e9af>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['dult'] = df['adult'].map({'False':False,'True':True})

# %%
df['adult'].value_counts()
# Out:
# adult
# False    45454
# True         9
# Name: count, dtype: int64

# %%
df['adult'].isnull().sum()
# Out:
# 0

# %%
df['adult'] = df['adult'].astype('bool')
# Out:
# <ipython-input-78-cf342a6cb396>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['adult'] = df['adult'].astype('bool')

# %%
df['adult'].value_counts()
# Out:
# adult
# True    45463
# Name: count, dtype: int64

# %%
df.columns
# Out:
# Index(['adult', 'belongs_to_collection', 'budget', 'genres', 'homepage', 'id',
#        'imdb_id', 'original_language', 'original_title', 'overview',
#        'popularity', 'poster_path', 'production_companies',
#        'production_countries', 'release_date', 'revenue', 'runtime',
#        'spoken_languages', 'status', 'tagline', 'title', 'video',
#        'vote_average', 'vote_count', 'dult'],
#       dtype='object')

# %% [markdown]
# #belongs to the collection

# %%
import numpy as np

# %%
df['belongs_to_collection'].values[0]#entire index values
# Out:
# "{'id': 10194, 'name': 'Toy Story Collection', 'poster_path': '/7G9915LfUQ2lVfwMEEhDsn3kT4B.jpg', 'backdrop_path': '/9FBwqcd9IRruEDUrTdcaafOMKUq.jpg'}"

# %%
df['belongs_to_collection'].head(1)
# Out:
# 0    {'id': 10194, 'name': 'Toy Story Collection', ...
# Name: belongs_to_collection, dtype: object

# %%
df['belongs_to_collection'].values
# Out:
# array(["{'id': 10194, 'name': 'Toy Story Collection', 'poster_path': '/7G9915LfUQ2lVfwMEEhDsn3kT4B.jpg', 'backdrop_path': '/9FBwqcd9IRruEDUrTdcaafOMKUq.jpg'}",
#        nan,
#        "{'id': 119050, 'name': 'Grumpy Old Men Collection', 'poster_path': '/nLvUdqgPgm3F85NMCii9gVFUcet.jpg', 'backdrop_path': '/hypTnLot2z8wpFS7qwsQHW1uV8u.jpg'}",
#        ..., nan, nan, nan], dtype=object)

# %%
a = {
    'id': 10194, 'name': 'Toy Story Collection',
    'poster_path': '/7G9915LfUQ2lVfwMEEhDsn3kT4B.jpg',
    'backdrop_path': '/9FBwqcd9IRruEDUrTdcaafOMKUq.jpg',

    }

# %% [markdown]
# #05/12/2024

# %%
import pandas as pd

# %%
df.columns
# Out:
# Index(['adult', 'belongs_to_collection', 'budget', 'genres', 'homepage', 'id',
#        'imdb_id', 'original_language', 'original_title', 'overview',
#        'popularity', 'poster_path', 'production_companies',
#        'production_countries', 'release_date', 'revenue', 'runtime',
#        'spoken_languages', 'status', 'tagline', 'title', 'video',
#        'vote_average', 'vote_count', 'dult'],
#       dtype='object')

# %%
df['genres'].values[0]
# Out:
# "[{'id': 16, 'name': 'Animation'}, {'id': 35, 'name': 'Comedy'}, {'id': 10751, 'name': 'Family'}]"

# %%
df['genres'].unique()
# Out:
# array(["[{'id': 16, 'name': 'Animation'}, {'id': 35, 'name': 'Comedy'}, {'id': 10751, 'name': 'Family'}]",
#        "[{'id': 12, 'name': 'Adventure'}, {'id': 14, 'name': 'Fantasy'}, {'id': 10751, 'name': 'Family'}]",
#        "[{'id': 10749, 'name': 'Romance'}, {'id': 35, 'name': 'Comedy'}]",
#        ...,
#        "[{'id': 80, 'name': 'Crime'}, {'id': 35, 'name': 'Comedy'}, {'id': 28, 'name': 'Action'}, {'id': 10751, 'name': 'Family'}]",
#        "[{'id': 28, 'name': 'Action'}, {'id': 9648, 'name': 'Mystery'}, {'id': 53, 'name': 'Thriller'}, {'id': 27, 'name': 'Horror'}]",
#        "[{'id': 10751, 'name': 'Family'}, {'id': 16, 'name': 'Animation'}, {'id': 10749, 'name': 'Romance'}, {'id': 35, 'name': 'Comedy'}]"],
#       dtype=object)

# %%
import ast #convrt arrays into string
ast.literal_eval(df['genres'].values[0])
# Out:
# [{'id': 16, 'name': 'Animation'},
#  {'id': 35, 'name': 'Comedy'},
#  {'id': 10751, 'name': 'Family'}]

# %%
#create a column for each generas ---- and say 1 if the movie have that genre,else put 0
a = {1,2}
a
# Out:
# {1, 2}

# %%
set([1,1,1,2,2,3,4,3,3])
# Out:
# {1, 2, 3, 4}

# %%
#we are going to look at the data and find & put all the unique genres
unique = set()
for i in df['genres']:
  #print(i)
  gen_list = ast.literal_eval(i) #converts from string to list of dict
  for j in gen_list:
    unique.add(j['name'])
print(unique)
# Out:
# {'Music', 'Crime', 'Animation', 'Romance', 'Foreign', 'Horror', 'History', 'Western', 'Documentary', 'Fantasy', 'Action', 'Adventure', 'Comedy', 'Family', 'War', 'Science Fiction', 'Mystery', 'Thriller', 'TV Movie', 'Drama'}

# %%
len(unique)
# Out:
# 20

# %%
rows = []
genres = list(unique)
for i in df['genres']:
  gen_list  = ast.literal_eval(i)
  movie_genres = [x['name'] for x in gen_list]
  row = [] #going to store 1's and 0's
  for j in genres:
      row.append(int(j in movie_genres)) # checking weather the genres are present or not
  row.append(row)

# %%
row
# Out:
# [1, 1, 0, 0]

# %%
movie_genres = ['Action','Adventure']
unique = ['Action','Adventure','Family','horror']
row = []
for j in unique:
  row.append(int(j in movie_genres))
row
# Out:
# [1, 1, 0, 0]

# %%
genre = pd.DataFrame(rows,columns = genres)

# %%
genre
# Out:
# Empty DataFrame
# Columns: [Music, Crime, Animation, Romance, Foreign, Horror, History, Western, Documentary, Fantasy, Action, Adventure, Comedy, Family, War, Science Fiction, Mystery, Thriller, TV Movie, Drama]
# Index: []

# %%
genre.shape
# Out:
# (0, 20)

# %%
df.shape
# Out:
# (45463, 25)

# %%
df
# Out:
#        adult                              belongs_to_collection    budget  \
# 0       True  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1       True                                                NaN  65000000
# 2       True  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3       True                                                NaN  16000000
# 4       True  {'id': 96871, 'name': 'Father of the Bride Col...         0
# ...      ...                                                ...       ...
# 45461   True                                                NaN         0
# 45462   True                                                NaN         0
# 45463   True                                                NaN         0
# 45464   True                                                NaN         0
# 45465   True                                                NaN         0
#
#                                                   genres  \
# ...

# %% [markdown]
# #homepages

# %%
df['homepage']
# Out:
# 0        http://toystory.disney.com/toy-story
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
#                          ...
# 45461    http://www.imdb.com/title/tt6209470/
# 45462                                     NaN
# 45463                                     NaN
# 45464                                     NaN
# 45465                                     NaN
# Name: homepage, Length: 45463, dtype: object

# %%
df.isnull().sum()
# Out:
# adult                        0
# belongs_to_collection    40972
# budget                       0
# genres                       0
# homepage                 37684
# id                           0
# imdb_id                     17
# original_language           11
# original_title               0
# overview                   954
# popularity                   3
# poster_path                386
# production_companies         3
# production_countries         3
# release_date                87
# revenue                      3
# runtime                    260
# spoken_languages             3
# status                      84
# tagline                  25051
# title                        3
# video                        3
# vote_average                 3
# vote_count                   3
# dult                         0
# dtype: int64

# %%
#calculate the percentage of this null value
df['homepage'].isnull().sum()*100/ df.shape[0]
# Out:
# 82.88938257484108

# %%
df['homepage_present'] = (~df['homepage'].isnull())
# Out:
# <ipython-input-160-b103a418dec2>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['homepage_present'] = (~df['homepage'].isnull())

# %%
df
# Out:
#        adult                              belongs_to_collection    budget  \
# 0       True  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1       True                                                NaN  65000000
# 2       True  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3       True                                                NaN  16000000
# 4       True  {'id': 96871, 'name': 'Father of the Bride Col...         0
# ...      ...                                                ...       ...
# 45461   True                                                NaN         0
# 45462   True                                                NaN         0
# 45463   True                                                NaN         0
# 45464   True                                                NaN         0
# 45465   True                                                NaN         0
#
#                                                   genres  \
# ...

# %%
df = df.drop(columns = ['homepage'])

# %%
df
# Out:
#        adult                              belongs_to_collection    budget  \
# 0       True  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1       True                                                NaN  65000000
# 2       True  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3       True                                                NaN  16000000
# 4       True  {'id': 96871, 'name': 'Father of the Bride Col...         0
# ...      ...                                                ...       ...
# 45461   True                                                NaN         0
# 45462   True                                                NaN         0
# 45463   True                                                NaN         0
# 45464   True                                                NaN         0
# 45465   True                                                NaN         0
#
#                                                   genres      id    imdb_id  \
# ...

# %% [markdown]
# #ID

# %%
df['id']
# Out:
# 0           862
# 1          8844
# 2         15602
# 3         31357
# 4         11862
#           ...
# 45461    439050
# 45462    111109
# 45463     67758
# 45464    227506
# 45465    461257
# Name: id, Length: 45463, dtype: object

# %%
df['id'].unique()
# Out:
# array(['862', '8844', '15602', ..., '67758', '227506', '461257'],
#       dtype=object)

# %%
len(df['id'].unique())
# Out:
# 45433

# %%
#drop the duplicates
df = df.drop_duplicates(subset = ['id'])
df.shape
# Out:
# (45433, 25)

# %%
df['id'] = df['id'].astype('int64')

# %%
df['id'].isnull().sum()
# Out:
# 0

# %%
df['id']
# Out:
# 0           862
# 1          8844
# 2         15602
# 3         31357
# 4         11862
#           ...
# 45461    439050
# 45462    111109
# 45463     67758
# 45464    227506
# 45465    461257
# Name: id, Length: 45433, dtype: int64

# %%
#we can delete tanglane,imdb,poster path
